# %%
# Kết nối đến Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2
import numpy as np
import os
from google.colab.patches import cv2_imshow

# %%
path = '/content/drive/MyDrive/text_opencv'
# Hiển thị tất cả thư mục hoặc file
os.listdir(path)
# Out:
# ['img_20.jpg',
#  'img_40.jpg',
#  'img_80.jpg',
#  'img_60.jpg',
#  'img_100.jpg',
#  'img_140.jpg',
#  'img_120.jpg',
#  'img_160.jpg',
#  'img_180.jpg',
#  'img_200.jpg',
#  'img_220.jpg',
#  'img_260.jpg',
#  'img_240.jpg',
#  'img_280.jpg',
#  'img_300.jpg',
#  'img_320.jpg',
#  'img_340.jpg',
#  'img_380.jpg',
#  'img_360.jpg',
#  'img_400.jpg',
#  'img_440.jpg',
#  'img_420.jpg',
#  'img_460.jpg',
#  'img_500.jpg',
#  'img_480.jpg',
#  'img_520.jpg',
#  'img_560.jpg',
#  'img_540.jpg',
#  'img_580.jpg',
#  'img_620.jpg',
#  'img_600.jpg',
#  'img_640.jpg',
#  'img_660.jpg',
#  'img_680.jpg',
#  'img_700.jpg',
#  'img_720.jpg',
#  'img_740.jpg',
#  'img_760.jpg',
#  'img_780.jpg',
#  'img_800.jpg',
#  'img_820.jpg',
#  'img_840.jpg',
#  'img_860.jpg',
#  'img_880.jpg',
#  'img_920.jpg',
#  'img_900.jpg',
#  'img_940.jpg',
#  'img_960.jpg',
#  'img_980.jpg',
#  'img_1000.jpg',
#  'img_1020.jpg',
#  'img_1040.jpg',
#  'img_1060.jpg',
#  'Bt27.ipynb',
#  'BT30.ipynb',
#  'models',
#  'FaceImage',
#  'data_face_features.pickle',
#  '31.ipynb',
#  'BT28.ipynb',
#  'BT29.ipynb']

# %%
# Hiển thị một ảnh
img = cv2.imread(path + "/img_1040.jpg")
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=640x480>
